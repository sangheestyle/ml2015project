# %% [markdown]
# # Model15: DPGMM l1_ratios for ElasticNetCV

# %% [markdown]
# ## Result on Kaggle
# l1_ratio
#
# * 0.2: 83.26356
# * 0.5: 81.66881
# * 0.6: 81.33149
# * **0.7: 81.23193**
# * 0.8: 81.55633
# * 0.9: 81.69428

# %% [markdown]
# ## A. Functions
#
# There have four different functions.
#
# * Data reader: Read data from file.
# * Feature functions(private): Functions which extract features are placed in here. It means that if you make a specific feature function, you can add the one into here.
# * Feature function(public): We can use only this function for feature extraction.
# * Utility functions: All the funtions except functions which are mentioned in above should be placed in here.

# %% [markdown]
# ### Data reader

# %%
import gzip
import pickle
from os import path
from collections import defaultdict
from numpy import sign


"""
Load buzz data as a dictionary.
You can give parameter for data so that you will get what you need only.
"""
def load_buzz(root='../data', data=['train', 'test', 'questions'], format='pklz'):
    buzz_data = {}
    for ii in data:
        file_path = path.join(root, ii + "." + format)
        with gzip.open(file_path, "rb") as fp:
          buzz_data[ii] = pickle.load(fp)
        
    return buzz_data

# %% [markdown]
# ### Feature functions(private)

# %%
from numpy import sign, abs


def _feat_basic(bd, group):
    X = []
    for item in bd[group].items():
        qid = item[1]['qid']
        q = bd['questions'][qid]
        #item[1]['q_length'] = max(q['pos_token'].keys())
        item[1]['q_length'] = len(q['question'].split())
        item[1]['category'] = q['category'].lower()
        item[1]['answer'] = q['answer'].lower()
        X.append(item[1])
        
    return X
        
        
def _feat_sign_val(data):
    for item in data:
        item['sign_val'] = sign(item['position'])

def _get_pos(bd, sign_val=None):
    # bd is not bd, bd is bd['train']
    unwanted_index = []
    pos_uid = defaultdict(list)
    pos_qid = defaultdict(list)
    
    for index, key in enumerate(bd):
        if sign_val and sign(bd[key]['position']) != sign_val:
            unwanted_index.append(index)
        else:
            pos_uid[bd[key]['uid']].append(bd[key]['position'])
            pos_qid[bd[key]['qid']].append(bd[key]['position'])
    
    return pos_uid, pos_qid, unwanted_index


def _get_avg_pos(bd, sign_val=None):
    pos_uid, pos_qid, unwanted_index = _get_pos(bd, sign_val)

    avg_pos_uid = {}
    avg_pos_qid = {}
    
    if not sign_val:
        sign_val = 1

    for key in pos_uid:
        pos = pos_uid[key]
        avg_pos_uid[key] = sign_val * (sum(pos) / len(pos))

    for key in pos_qid:
        pos = pos_qid[key]
        avg_pos_qid[key] = sign_val * (sum(pos) / len(pos))
    
    return avg_pos_uid, avg_pos_qid, unwanted_index

        
def _feat_avg_pos(data, bd, group, sign_val):
    avg_pos_uid, avg_pos_qid, unwanted_index = _get_avg_pos(bd['train'], sign_val=sign_val)
    
    if group == 'train':
        for index in sorted(unwanted_index, reverse=True):
            del data[index]
    
    for item in data:
        if item['uid'] in avg_pos_uid:
            item['avg_pos_uid'] = avg_pos_uid[item['uid']]
        else:
            vals = avg_pos_uid.values()
            item['avg_pos_uid'] = sum(vals) / float(len(vals))
              
        if item['qid'] in avg_pos_qid:
            item['avg_pos_qid'] = avg_pos_qid[item['qid']]
        else:
            vals = avg_pos_qid.values()
            item['avg_pos_qid'] = sum(vals) / float(len(vals))
        
        # Response position can be longer than length of question
        if item['avg_pos_uid'] > item['q_length']:
            item['avg_pos_uid'] = item['q_length']
        
        if item['avg_pos_qid'] > item['q_length']:
            item['avg_pos_qid'] = item['q_length']

# %% [markdown]
# ### Feature function(public)

# %%
def featurize(bd, group, sign_val=None, extra=None):
    # Basic features
    # qid(string), uid(string), position(float)
    # answer'(string), 'potistion'(float), 'qid'(string), 'uid'(string)
    X = _feat_basic(bd, group=group)
    
    # Some extra features
    if extra:
        for func_name in extra:
            func_name = '_feat_' + func_name
            if func_name in ['_feat_avg_pos']:
                globals()[func_name](X, bd, group=group, sign_val=sign_val)
            else:
                globals()[func_name](X)
    
    if group == 'train':
        y = []
        for item in X:
            y.append(item['position'])
            del item['position']

        return X, y
    elif group == 'test':
        return X
    else:
        raise ValueError(group, 'is not the proper type')

# %% [markdown]
# ### Utility functions

# %%
import csv


def select(data, keys):
    unwanted = data[0].keys() - keys
    for item in data:
        for unwanted_key in unwanted:
            del item[unwanted_key]
    return data


def write_result(test_set, predictions, file_name='guess.csv'):
    predictions = sorted([[id, predictions[index]] for index, id in enumerate(test_set.keys())])
    predictions.insert(0,["id", "position"])
    with open(file_name, "w") as fp:
        writer = csv.writer(fp, delimiter=',')
        writer.writerows(predictions)

# %% [markdown]
# ## GMM

# %% [markdown]
# ### Classifying questions
# features: avg_pos, accuracy rate

# %%
# %matplotlib inline
import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn import mixture


def plot_gmm(X, models, n_components, covariance_type='diag', n_iter=100,
            figsize=(10, 20), suptitle=None, xlabel=None, ylabel=None):
    color_iter = ['r', 'g', 'b', 'c', 'm', 'y', 'k', 'gray', 'pink', 'lime']
    plt.figure(figsize=figsize)
    plt.suptitle(suptitle, fontsize=20)

    for i, model in enumerate(models):
        mm = getattr(mixture, model)(n_components=n_components,
                                     covariance_type=covariance_type,
                                     n_iter=n_iter)
        mm.fit(X_pos_qid)
        Y = mm.predict(X_pos_qid)

        plt.subplot(len(models), 1, 1 + i)
        for i, color in enumerate(color_iter):
            plt.scatter(X_pos_qid[Y == i, 0], X_pos_qid[Y == i, 1], .7, color=color)
        plt.title(model, fontsize=15)
        plt.xlabel(xlabel, fontsize=12)
        plt.ylabel(ylabel, fontsize=12)
        plt.grid()

    plt.show()

# %%
from collections import UserDict, defaultdict
import numpy as np


class DictDict(UserDict):
    def __init__(self, bd):
        UserDict.__init__(self)
        self._set_bd(bd)
        
    def sub_keys(self):
        return self[list(self.keys())[0]].keys()
            
    def select(self, sub_keys):
        vals = []
        for key in self:
            vals.append([self[key][sub_key] for sub_key in sub_keys])
        return np.array(vals)
    
    def sub_append(self, sub_key, values):
        for index, key in enumerate(self):
            self[key][sub_key] = values[index]

    
class Users(DictDict):
    def _set_bd(self, bd):
        pos_uid, _, _ = _get_pos(bd['train'], sign_val=None)
        for key in pos_uid:
            u = np.array(pos_uid[key])
            ave_pos_uid = sum(abs(u)) / float(len(u))
            acc_ratio_uid = len(u[u > 0]) / float(len(u))
            self[key] = {'ave_pos_uid': ave_pos_uid,
                         'acc_ratio_uid': acc_ratio_uid}

            
class Questions(DictDict):
    def _set_bd(self, bd):
        _, pos_qid, _ = _get_pos(bd['train'], sign_val=None)
        
        for key in pos_qid:
            u = np.array(pos_qid[key])
            ave_pos_qid = sum(abs(u)) / float(len(u))
            acc_ratio_qid = len(u[u > 0]) / float(len(u))
            self[key] = bd['questions'][key]
            self[key]['ave_pos_qid'] = ave_pos_qid
            self[key]['acc_ratio_qid'] = acc_ratio_qid

class Categories(DictDict):
    def _set_bd(self, bd):
        _, pos_qid, _ = _get_pos(bd['train'], sign_val=None)
        cat_qids = defaultdict(list)
        
        # Make {category: [qid, qid...]}
        for key in bd['questions']:
            q = bd['questions'][key]
            cat_qids[q['category'].lower()].append(key)
        
        for key in cat_qids:
            pos = []
            for qid in cat_qids[key]:
                pos += pos_qid[qid]
            pos = np.array(pos)
            ave_pos_cat = sum(pos) / float(len(pos))
            acc_ratio_cat = len(pos[pos > 0]) / float(len(pos))
            self[key] = {'ave_pos_cat': ave_pos_cat,
                         'acc_ratio_cat': acc_ratio_cat}

# %%
users = Users(load_buzz())
questions = Questions(load_buzz())
X_pos_uid = users.select(['ave_pos_uid', 'acc_ratio_uid'])
X_pos_qid = questions.select(['ave_pos_qid', 'acc_ratio_qid'])

# %%
plot_gmm(X_pos_uid,
         models=['GMM', 'VBGMM', 'DPGMM'],
         n_components=8,
         covariance_type='diag',
         figsize=(10, 20),
         suptitle='Classifying users',
         xlabel='abs(position)',
         ylabel='accuracy ratio')

# %%
plot_gmm(X_pos_qid,
         models=['GMM', 'VBGMM', 'DPGMM'],
         n_components=8,
         covariance_type='diag',
         figsize=(10, 20),
         suptitle='Classifying questions',
         xlabel='abs(position)',
         ylabel='accuracy ratio')

# %%
# Question category
n_components = 8
gmm = mixture.DPGMM(n_components=n_components, covariance_type='diag', n_iter=10**10)
gmm.fit(X_pos_qid)
pred_cat_qid = gmm.predict(X_pos_qid)

plt.hist(pred_cat_qid, bins=50, facecolor='g', alpha=0.75)
plt.xlabel("Category number")
plt.ylabel("Count")
plt.title("Question Category: " + str(n_components) + " categories")
plt.grid(True)
plt.show()

# %%
# User category
n_components = 8
gmm = mixture.DPGMM(n_components=n_components, covariance_type='diag', n_iter=10**10)
gmm.fit(X_pos_uid)
pred_cat_uid = gmm.predict(X_pos_uid)

plt.hist(pred_cat_uid, bins=50, facecolor='g', alpha=0.75)
plt.xlabel("Category number")
plt.ylabel("Count")
plt.title("User Category: " + str(n_components) + " categories")
plt.grid(True)
plt.show()

# %%
from collections import Counter


users.sub_append('cat_uid', [str(x) for x in pred_cat_uid])
questions.sub_append('cat_qid', [str(x) for x in pred_cat_qid])

# to get most frequent cat for some test data which do not have ids in train set
most_pred_cat_uid = Counter(pred_cat_uid).most_common(1)[0][0]
most_pred_cat_qid = Counter(pred_cat_qid).most_common(1)[0][0]

print(most_pred_cat_uid)
print(most_pred_cat_qid)
# Out:
# 3
# 6

# %%
print(users[1])
print(questions[1])
# Out:
# {'acc_ratio_uid': 0.6465863453815262, 'ave_pos_uid': 96.724899598393577, 'cat_uid': '3'}
# {'question': "This painter's indulgence of visual fantasy, and appreciation of different historic architectural styles can be seen in his 1840 Architect's Dream. After a series of paintings on The Last of the Mohicans, he made a three year trip to Europe in 1829, but he is better known for a trip four years earlier in which he journeyed up the Hudson River to the Catskill Mountains. FTP, name this painter of The Oxbow and The Voyage of Life series.", 'ave_pos_qid': 70.5, 'pos_token': {0: '', 1: 'painters', 2: 'indulgence', 4: 'visual', 5: 'fantasy', 68: 'this_painter', 7: 'appreciation', 64: 'mountains', 9: 'different', 10: 'historic', 11: 'architectural', 12: 'styles', 66: 'name', 77: 'series', 15: 'seen', 18: '1840', 19: 'architects', 20: 'dream', 23: 'series', 25: 'paintings', 28: 'last', 31: 'mohicans', 33: 'made', 35: 'three', 36: 'year', 37: 'trip', 65: 'ftp', 39: 'europe', 41: '1829', 71: 'oxbow', 45: 'better', 46: 'known', 76: 'life', 49: 'trip', 50: 'four', 51: 'years', 52: 'earlier', 56: 'journeyed', 59: 'hudson', 60: 'river', 74: 'voyage', 63: 'catskill'}, 'acc_ratio_qid': 0.875, 'group': 'test', 'cat_qid': '6', 'category': 'Fine Arts', 'answer': 'thomas cole'}

# %% [markdown]
# ## B. Modeling

# %% [markdown]
# ### Select model

# %%
regression_keys = ['category', 'q_length', 'qid', 'uid', 'answer', 'avg_pos_uid', 'avg_pos_qid']
X_train, y_train = featurize(load_buzz(), group='train', sign_val=None, extra=['sign_val', 'avg_pos'])
X_train = select(X_train, regression_keys)

# %%
categories = Categories(load_buzz())

# %%
for item in X_train:
    for key in categories[item['category']].keys():
        item[key] = categories[item['category']][key]

# %%
X_train
# Out:
# [{'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'thomas cole',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 51.0,
#   'avg_pos_uid': 55.708333333333336,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 1,
#   'uid': 0},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'thomas cole',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 51.0,
#   'avg_pos_uid': 30.973895582329316,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 1,
#   'uid': 1},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'thomas cole',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 51.0,
#   'avg_pos_uid': 36.72222222222222,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 1,
#   'uid': 2},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'thomas cole',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 51.0,
#   'avg_pos_uid': 49.65835411471322,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 1,
#   'uid': 3},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'thomas cole',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 51.0,
#   'avg_pos_uid': 72.65142857142857,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 1,
#   'uid': 4},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'thomas cole',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 51.0,
#   'avg_pos_uid': 38.608695652173914,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 1,
#   'uid': 5},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'thomas cole',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 51.0,
#   'avg_pos_uid': 26.897727272727273,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 1,
#   'uid': 7},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'thomas cole',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 51.0,
#   'avg_pos_uid': 8.571428571428571,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 1,
#   'uid': 8},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'rococo',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 68.0,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 4,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'swing',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 75.0,
#   'avg_pos_uid': 48.99321266968326,
#   'category': 'literature',
#   'q_length': 75,
#   'qid': 5,
#   'uid': 10},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'swing',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 75.0,
#   'avg_pos_uid': 53.590062111801245,
#   'category': 'literature',
#   'q_length': 75,
#   'qid': 5,
#   'uid': 11},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'swing',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 75.0,
#   'avg_pos_uid': 30.973895582329316,
#   'category': 'literature',
#   'q_length': 75,
#   'qid': 5,
#   'uid': 1},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'el greco',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 49.833333333333336,
#   'avg_pos_uid': 30.833333333333332,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 6,
#   'uid': 13},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'el greco',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 49.833333333333336,
#   'avg_pos_uid': 38.577586206896555,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 6,
#   'uid': 14},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'el greco',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 49.833333333333336,
#   'avg_pos_uid': 31.45751633986928,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 6,
#   'uid': 12},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'el greco',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 49.833333333333336,
#   'avg_pos_uid': 49.65835411471322,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 6,
#   'uid': 3},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'el greco',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 49.833333333333336,
#   'avg_pos_uid': 45.63157894736842,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 6,
#   'uid': 15},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'el greco',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 49.833333333333336,
#   'avg_pos_uid': 38.09090909090909,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 6,
#   'uid': 16},
#  {'acc_ratio_cat': 0.7069788249328959,
#   'answer': 'max weber',
#   'ave_pos_cat': 33.599761407694601,
#   'avg_pos_qid': 84.75,
#   'avg_pos_uid': 49.20206489675516,
#   'category': 'social studies',
#   'q_length': 100,
#   'qid': 10924,
#   'uid': 18},
#  {'acc_ratio_cat': 0.7069788249328959,
#   'answer': 'max weber',
#   'ave_pos_cat': 33.599761407694601,
#   'avg_pos_qid': 84.75,
#   'avg_pos_uid': 35.77872340425532,
#   'category': 'social studies',
#   'q_length': 100,
#   'qid': 10924,
#   'uid': 19},
#  {'acc_ratio_cat': 0.7069788249328959,
#   'answer': 'max weber',
#   'ave_pos_cat': 33.599761407694601,
#   'avg_pos_qid': 84.75,
#   'avg_pos_uid': 55.74681753889675,
#   'category': 'social studies',
#   'q_length': 100,
#   'qid': 10924,
#   'uid': 20},
#  {'acc_ratio_cat': 0.7069788249328959,
#   'answer': 'max weber',
#   'ave_pos_cat': 33.599761407694601,
#   'avg_pos_qid': 84.75,
#   'avg_pos_uid': 38.577586206896555,
#   'category': 'social studies',
#   'q_length': 100,
#   'qid': 10924,
#   'uid': 14},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 30.5,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 75,
#   'qid': 11,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 30.5,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 75,
#   'qid': 11,
#   'uid': 9},
#  {'acc_ratio_cat': 0.65625,
#   'answer': 'nicolas poussin',
#   'ave_pos_cat': 18.712499999999999,
#   'avg_pos_qid': 62.5,
#   'avg_pos_uid': 52.05338078291815,
#   'category': 'mathematics',
#   'q_length': 64,
#   'qid': 19,
#   'uid': 22},
#  {'acc_ratio_cat': 0.65625,
#   'answer': 'nicolas poussin',
#   'ave_pos_cat': 18.712499999999999,
#   'avg_pos_qid': 62.5,
#   'avg_pos_uid': 64,
#   'category': 'mathematics',
#   'q_length': 64,
#   'qid': 19,
#   'uid': 4},
#  {'acc_ratio_cat': 0.7069788249328959,
#   'answer': 'haywain',
#   'ave_pos_cat': 33.599761407694601,
#   'avg_pos_qid': 68.0,
#   'avg_pos_uid': 27.819887429643526,
#   'category': 'social studies',
#   'q_length': 97,
#   'qid': 35,
#   'uid': 23},
#  {'acc_ratio_cat': 0.7069788249328959,
#   'answer': 'haywain',
#   'ave_pos_cat': 33.599761407694601,
#   'avg_pos_qid': 68.0,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'social studies',
#   'q_length': 97,
#   'qid': 35,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7069788249328959,
#   'answer': 'haywain',
#   'ave_pos_cat': 33.599761407694601,
#   'avg_pos_qid': 68.0,
#   'avg_pos_uid': 55.74681753889675,
#   'category': 'social studies',
#   'q_length': 97,
#   'qid': 35,
#   'uid': 20},
#  {'acc_ratio_cat': 0.7069788249328959,
#   'answer': 'haywain',
#   'ave_pos_cat': 33.599761407694601,
#   'avg_pos_qid': 68.0,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'social studies',
#   'q_length': 97,
#   'qid': 35,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7069788249328959,
#   'answer': 'haywain',
#   'ave_pos_cat': 33.599761407694601,
#   'avg_pos_qid': 68.0,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'social studies',
#   'q_length': 97,
#   'qid': 35,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7069788249328959,
#   'answer': 'haywain',
#   'ave_pos_cat': 33.599761407694601,
#   'avg_pos_qid': 68.0,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'social studies',
#   'q_length': 97,
#   'qid': 35,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7069788249328959,
#   'answer': 'haywain',
#   'ave_pos_cat': 33.599761407694601,
#   'avg_pos_qid': 68.0,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'social studies',
#   'q_length': 97,
#   'qid': 35,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'swing',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 51.333333333333336,
#   'avg_pos_uid': 49.20206489675516,
#   'category': 'fine arts',
#   'q_length': 77,
#   'qid': 36,
#   'uid': 18},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'swing',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 51.333333333333336,
#   'avg_pos_uid': 49.725247524752476,
#   'category': 'fine arts',
#   'q_length': 77,
#   'qid': 36,
#   'uid': 24},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'swing',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 51.333333333333336,
#   'avg_pos_uid': 23.157894736842106,
#   'category': 'fine arts',
#   'q_length': 77,
#   'qid': 36,
#   'uid': 25},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'swing',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 51.333333333333336,
#   'avg_pos_uid': 38.608695652173914,
#   'category': 'fine arts',
#   'q_length': 77,
#   'qid': 36,
#   'uid': 5},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'swing',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 51.333333333333336,
#   'avg_pos_uid': 34.97027027027027,
#   'category': 'fine arts',
#   'q_length': 77,
#   'qid': 36,
#   'uid': 27},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'swing',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 51.333333333333336,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 77,
#   'qid': 36,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'tempest',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.0,
#   'avg_pos_uid': 46.93333333333333,
#   'category': 'fine arts',
#   'q_length': 82,
#   'qid': 42,
#   'uid': 28},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'tempest',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.0,
#   'avg_pos_uid': -2.2989690721649483,
#   'category': 'fine arts',
#   'q_length': 82,
#   'qid': 42,
#   'uid': 29},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'tempest',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.0,
#   'avg_pos_uid': 49.65835411471322,
#   'category': 'fine arts',
#   'q_length': 82,
#   'qid': 42,
#   'uid': 3},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'marc chagall',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 46.0,
#   'avg_pos_uid': 49.65835411471322,
#   'category': 'fine arts',
#   'q_length': 92,
#   'qid': 44,
#   'uid': 3},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'peter paul rubens',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 77.0,
#   'avg_pos_uid': 42.727659574468085,
#   'category': 'fine arts',
#   'q_length': 77,
#   'qid': 46,
#   'uid': 30},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'peter paul rubens',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 77.0,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 77,
#   'qid': 46,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'peter paul rubens',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 77.0,
#   'avg_pos_uid': 33.91011235955056,
#   'category': 'fine arts',
#   'q_length': 77,
#   'qid': 46,
#   'uid': 31},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'olympia',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 28.785714285714285,
#   'avg_pos_uid': 21.65714285714286,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 49,
#   'uid': 32},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'olympia',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 28.785714285714285,
#   'avg_pos_uid': 51.770270270270274,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 49,
#   'uid': 33},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'olympia',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 28.785714285714285,
#   'avg_pos_uid': 55.90780141843972,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 49,
#   'uid': 26},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'olympia',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 28.785714285714285,
#   'avg_pos_uid': 26.0,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 49,
#   'uid': 34},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'olympia',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 28.785714285714285,
#   'avg_pos_uid': 5.277777777777778,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 49,
#   'uid': 35},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'olympia',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 28.785714285714285,
#   'avg_pos_uid': 21.72222222222222,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 49,
#   'uid': 36},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'olympia',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 28.785714285714285,
#   'avg_pos_uid': 55.204081632653065,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 49,
#   'uid': 37},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'olympia',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 28.785714285714285,
#   'avg_pos_uid': 30.973895582329316,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 49,
#   'uid': 1},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'olympia',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 28.785714285714285,
#   'avg_pos_uid': -17.846153846153847,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 49,
#   'uid': 38},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'olympia',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 28.785714285714285,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 49,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'olympia',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 28.785714285714285,
#   'avg_pos_uid': 24.63529411764706,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 49,
#   'uid': 39},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'olympia',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 28.785714285714285,
#   'avg_pos_uid': 48.51677852348993,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 49,
#   'uid': 40},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'olympia',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 28.785714285714285,
#   'avg_pos_uid': 61.37362637362637,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 49,
#   'uid': 41},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'olympia',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 28.785714285714285,
#   'avg_pos_uid': 51.299546142208776,
#   'category': 'fine arts',
#   'q_length': 76,
#   'qid': 49,
#   'uid': 42},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'a hero of our time',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 30.5,
#   'avg_pos_uid': 48.99321266968326,
#   'category': 'literature',
#   'q_length': 59,
#   'qid': 5470,
#   'uid': 10},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'a hero of our time',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 30.5,
#   'avg_pos_uid': 33.91011235955056,
#   'category': 'literature',
#   'q_length': 59,
#   'qid': 5470,
#   'uid': 31},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'gustave courbet',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 145.5,
#   'avg_pos_uid': 49.725247524752476,
#   'category': 'literature',
#   'q_length': 148,
#   'qid': 61,
#   'uid': 24},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'gustave courbet',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 145.5,
#   'avg_pos_uid': -2.2989690721649483,
#   'category': 'literature',
#   'q_length': 148,
#   'qid': 61,
#   'uid': 29},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'middlemarch',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 21.0,
#   'avg_pos_uid': 46.93333333333333,
#   'category': 'literature',
#   'q_length': 52,
#   'qid': 5473,
#   'uid': 28},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'middlemarch',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 21.0,
#   'avg_pos_uid': 27.819887429643526,
#   'category': 'literature',
#   'q_length': 52,
#   'qid': 5473,
#   'uid': 23},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'a room with a view',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 13.454545454545455,
#   'avg_pos_uid': 70.61417322834646,
#   'category': 'literature',
#   'q_length': 129,
#   'qid': 6549,
#   'uid': 44},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'a room with a view',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 13.454545454545455,
#   'avg_pos_uid': 38.577586206896555,
#   'category': 'literature',
#   'q_length': 129,
#   'qid': 6549,
#   'uid': 14},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'a room with a view',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 13.454545454545455,
#   'avg_pos_uid': 31.45751633986928,
#   'category': 'literature',
#   'q_length': 129,
#   'qid': 6549,
#   'uid': 12},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'a room with a view',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 13.454545454545455,
#   'avg_pos_uid': 46.93333333333333,
#   'category': 'literature',
#   'q_length': 129,
#   'qid': 6549,
#   'uid': 28},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'a room with a view',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 13.454545454545455,
#   'avg_pos_uid': 55.51875,
#   'category': 'literature',
#   'q_length': 129,
#   'qid': 6549,
#   'uid': 45},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'a room with a view',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 13.454545454545455,
#   'avg_pos_uid': 30.833333333333332,
#   'category': 'literature',
#   'q_length': 129,
#   'qid': 6549,
#   'uid': 13},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'a room with a view',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 13.454545454545455,
#   'avg_pos_uid': 58.64485981308411,
#   'category': 'literature',
#   'q_length': 129,
#   'qid': 6549,
#   'uid': 47},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'a room with a view',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 13.454545454545455,
#   'avg_pos_uid': 5.277777777777778,
#   'category': 'literature',
#   'q_length': 129,
#   'qid': 6549,
#   'uid': 35},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'a room with a view',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 13.454545454545455,
#   'avg_pos_uid': 13.670454545454545,
#   'category': 'literature',
#   'q_length': 129,
#   'qid': 6549,
#   'uid': 48},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'a room with a view',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 13.454545454545455,
#   'avg_pos_uid': 13.788617886178862,
#   'category': 'literature',
#   'q_length': 129,
#   'qid': 6549,
#   'uid': 49},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'a room with a view',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 13.454545454545455,
#   'avg_pos_uid': -21.259515570934255,
#   'category': 'literature',
#   'q_length': 129,
#   'qid': 6549,
#   'uid': 50},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'thomas cole',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 20.857142857142858,
#   'avg_pos_uid': 49.20206489675516,
#   'category': 'fine arts',
#   'q_length': 93,
#   'qid': 79,
#   'uid': 18},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'thomas cole',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 20.857142857142858,
#   'avg_pos_uid': 52.05338078291815,
#   'category': 'fine arts',
#   'q_length': 93,
#   'qid': 79,
#   'uid': 22},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'thomas cole',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 20.857142857142858,
#   'avg_pos_uid': 29.251351351351353,
#   'category': 'fine arts',
#   'q_length': 93,
#   'qid': 79,
#   'uid': 52},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'thomas cole',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 20.857142857142858,
#   'avg_pos_uid': -19.10857142857143,
#   'category': 'fine arts',
#   'q_length': 93,
#   'qid': 79,
#   'uid': 53},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'thomas cole',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 20.857142857142858,
#   'avg_pos_uid': 55.90780141843972,
#   'category': 'fine arts',
#   'q_length': 93,
#   'qid': 79,
#   'uid': 26},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'thomas cole',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 20.857142857142858,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 93,
#   'qid': 79,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'thomas cole',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 20.857142857142858,
#   'avg_pos_uid': 58.64485981308411,
#   'category': 'fine arts',
#   'q_length': 93,
#   'qid': 79,
#   'uid': 47},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 35.77872340425532,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 19},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 27.819887429643526,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 23},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 53.559471365638764,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 54},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 38.577586206896555,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 14},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 57.680851063829785,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 55},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 38.09090909090909,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 16},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 21.65714285714286,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 32},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 78,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 56},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 23.157894736842106,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 25},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 33.52439024390244,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 57},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': -13.975609756097562,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 58},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': -16.507246376811594,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 59},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 50.55555555555556,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 61},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 31.233590733590734,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 62},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 44.89887640449438,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 63},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 26.897727272727273,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 7},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 61.37362637362637,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 41},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 62.46045694200352,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 64},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 45.63157894736842,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 15},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 34.97027027027027,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 27},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 65.30232558139535,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 65},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 19.442105263157895,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 66},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 24.903614457831324,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 17},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 41.88,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 67},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 8.571428571428571,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 8},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 55.1025641025641,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 69},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'eugene delacroix',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.51851851851852,
#   'avg_pos_uid': 33.91011235955056,
#   'category': 'fine arts',
#   'q_length': 78,
#   'qid': 81,
#   'uid': 31},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'isenheim altarpiece',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 42.333333333333336,
#   'avg_pos_uid': 46.93333333333333,
#   'category': 'fine arts',
#   'q_length': 102,
#   'qid': 82,
#   'uid': 28},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'isenheim altarpiece',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 42.333333333333336,
#   'avg_pos_uid': 55.708333333333336,
#   'category': 'fine arts',
#   'q_length': 102,
#   'qid': 82,
#   'uid': 0},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'isenheim altarpiece',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 42.333333333333336,
#   'avg_pos_uid': 34.97027027027027,
#   'category': 'fine arts',
#   'q_length': 102,
#   'qid': 82,
#   'uid': 27},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'henri rousseau',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': -8.25,
#   'avg_pos_uid': 38.577586206896555,
#   'category': 'fine arts',
#   'q_length': 100,
#   'qid': 83,
#   'uid': 14},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'henri rousseau',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': -8.25,
#   'avg_pos_uid': 55.74681753889675,
#   'category': 'fine arts',
#   'q_length': 100,
#   'qid': 83,
#   'uid': 20},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'henri rousseau',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': -8.25,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 100,
#   'qid': 83,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'henri rousseau',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': -8.25,
#   'avg_pos_uid': 31.45751633986928,
#   'category': 'fine arts',
#   'q_length': 100,
#   'qid': 83,
#   'uid': 12},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'swing',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 80.5,
#   'avg_pos_uid': 53.559471365638764,
#   'category': 'fine arts',
#   'q_length': 106,
#   'qid': 87,
#   'uid': 54},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'swing',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 80.5,
#   'avg_pos_uid': 75.7890625,
#   'category': 'fine arts',
#   'q_length': 106,
#   'qid': 87,
#   'uid': 70},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'swing',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 80.5,
#   'avg_pos_uid': 13.788617886178862,
#   'category': 'fine arts',
#   'q_length': 106,
#   'qid': 87,
#   'uid': 49},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'swing',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 80.5,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 106,
#   'qid': 87,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'henri matisse',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 96.16666666666667,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 113,
#   'qid': 90,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'henri matisse',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 96.16666666666667,
#   'avg_pos_uid': 49.971377459749554,
#   'category': 'fine arts',
#   'q_length': 113,
#   'qid': 90,
#   'uid': 71},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'henri matisse',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 96.16666666666667,
#   'avg_pos_uid': -2.2989690721649483,
#   'category': 'fine arts',
#   'q_length': 113,
#   'qid': 90,
#   'uid': 29},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'henri matisse',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 96.16666666666667,
#   'avg_pos_uid': 33.85839160839161,
#   'category': 'fine arts',
#   'q_length': 113,
#   'qid': 90,
#   'uid': 43},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'henri matisse',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 96.16666666666667,
#   'avg_pos_uid': 30.973895582329316,
#   'category': 'fine arts',
#   'q_length': 113,
#   'qid': 90,
#   'uid': 1},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'henri matisse',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 96.16666666666667,
#   'avg_pos_uid': 51.299546142208776,
#   'category': 'fine arts',
#   'q_length': 113,
#   'qid': 90,
#   'uid': 42},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'pierreauguste renoir',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 81.6,
#   'avg_pos_uid': 19.08108108108108,
#   'category': 'fine arts',
#   'q_length': 119,
#   'qid': 91,
#   'uid': 72},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'pierreauguste renoir',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 81.6,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 119,
#   'qid': 91,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'pierreauguste renoir',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 81.6,
#   'avg_pos_uid': 38.608695652173914,
#   'category': 'fine arts',
#   'q_length': 119,
#   'qid': 91,
#   'uid': 5},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'pierreauguste renoir',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 81.6,
#   'avg_pos_uid': 13.788617886178862,
#   'category': 'fine arts',
#   'q_length': 119,
#   'qid': 91,
#   'uid': 49},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'pierreauguste renoir',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 81.6,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 119,
#   'qid': 91,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'tempest',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.5,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 117,
#   'qid': 93,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'tempest',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.5,
#   'avg_pos_uid': 49.725247524752476,
#   'category': 'fine arts',
#   'q_length': 117,
#   'qid': 93,
#   'uid': 24},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'tempest',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.5,
#   'avg_pos_uid': 51.299546142208776,
#   'category': 'fine arts',
#   'q_length': 117,
#   'qid': 93,
#   'uid': 42},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'tempest',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 48.5,
#   'avg_pos_uid': 34.97027027027027,
#   'category': 'fine arts',
#   'q_length': 117,
#   'qid': 93,
#   'uid': 27},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'kiss',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 80.0,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 93,
#   'qid': 94,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'kiss',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 80.0,
#   'avg_pos_uid': 27.819887429643526,
#   'category': 'fine arts',
#   'q_length': 93,
#   'qid': 94,
#   'uid': 23},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'kiss',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 80.0,
#   'avg_pos_uid': 31.233590733590734,
#   'category': 'fine arts',
#   'q_length': 93,
#   'qid': 94,
#   'uid': 62},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'kiss',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 80.0,
#   'avg_pos_uid': 54.17412935323383,
#   'category': 'fine arts',
#   'q_length': 93,
#   'qid': 94,
#   'uid': 60},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'kiss',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 80.0,
#   'avg_pos_uid': 62.46045694200352,
#   'category': 'fine arts',
#   'q_length': 93,
#   'qid': 94,
#   'uid': 64},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'kiss',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 95.0,
#   'avg_pos_uid': 44.0092879256966,
#   'category': 'fine arts',
#   'q_length': 98,
#   'qid': 96,
#   'uid': 73},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'kiss',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 95.0,
#   'avg_pos_uid': 51.299546142208776,
#   'category': 'fine arts',
#   'q_length': 98,
#   'qid': 96,
#   'uid': 42},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'venus',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 91.0,
#   'avg_pos_uid': 51.299546142208776,
#   'category': 'fine arts',
#   'q_length': 91,
#   'qid': 99,
#   'uid': 42},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'tribute money',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 92.5,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 97,
#   'qid': 102,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'tribute money',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 92.5,
#   'avg_pos_uid': 46.93333333333333,
#   'category': 'fine arts',
#   'q_length': 97,
#   'qid': 102,
#   'uid': 28},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': 37.06896551724138,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 74},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': 38.577586206896555,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 14},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': 42.727659574468085,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 30},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': 43.375,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 75},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': 66.10526315789474,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 76},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': 53.5,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 77},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': 61.37362637362637,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 41},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': 48.15555555555556,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 78},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': 55.51875,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 45},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': 33.223880597014926,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 80},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': 38.22222222222222,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 81},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': -39.513513513513516,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 82},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': -13.916666666666666,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 83},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': -17.846153846153847,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 38},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': 51.299546142208776,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 42},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': 41.88,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 67},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': -21.259515570934255,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 50},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': 25.214285714285715,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 85},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': 40.333333333333336,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 86},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'garden of earthly delights',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 43.25,
#   'avg_pos_uid': 10.902439024390244,
#   'category': 'fine arts',
#   'q_length': 118,
#   'qid': 114,
#   'uid': 87},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'frans hals',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 39.0,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 94,
#   'qid': 118,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'john singer sargent',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 63.25,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 96,
#   'qid': 119,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'john singer sargent',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 63.25,
#   'avg_pos_uid': 49.971377459749554,
#   'category': 'fine arts',
#   'q_length': 96,
#   'qid': 119,
#   'uid': 71},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'john singer sargent',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 63.25,
#   'avg_pos_uid': 33.85839160839161,
#   'category': 'fine arts',
#   'q_length': 96,
#   'qid': 119,
#   'uid': 43},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'john singer sargent',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 63.25,
#   'avg_pos_uid': 49.65835411471322,
#   'category': 'fine arts',
#   'q_length': 96,
#   'qid': 119,
#   'uid': 3},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'bald soprano',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': -81.0,
#   'avg_pos_uid': 33.85839160839161,
#   'category': 'literature',
#   'q_length': 81,
#   'qid': 5482,
#   'uid': 43},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'edward hopper',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 47.2,
#   'avg_pos_uid': 27.819887429643526,
#   'category': 'fine arts',
#   'q_length': 64,
#   'qid': 128,
#   'uid': 23},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'edward hopper',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 47.2,
#   'avg_pos_uid': 60.06666666666667,
#   'category': 'fine arts',
#   'q_length': 64,
#   'qid': 128,
#   'uid': 88},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'edward hopper',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 47.2,
#   'avg_pos_uid': 51.299546142208776,
#   'category': 'fine arts',
#   'q_length': 64,
#   'qid': 128,
#   'uid': 42},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'edward hopper',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 47.2,
#   'avg_pos_uid': 34.97027027027027,
#   'category': 'fine arts',
#   'q_length': 64,
#   'qid': 128,
#   'uid': 27},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'edward hopper',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 47.2,
#   'avg_pos_uid': 51.770270270270274,
#   'category': 'fine arts',
#   'q_length': 64,
#   'qid': 128,
#   'uid': 33},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'sandro botticelli',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 108.28571428571429,
#   'avg_pos_uid': 49.725247524752476,
#   'category': 'fine arts',
#   'q_length': 111,
#   'qid': 132,
#   'uid': 24},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'sandro botticelli',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 108.28571428571429,
#   'avg_pos_uid': 42.727659574468085,
#   'category': 'fine arts',
#   'q_length': 111,
#   'qid': 132,
#   'uid': 30},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'sandro botticelli',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 108.28571428571429,
#   'avg_pos_uid': 49.971377459749554,
#   'category': 'fine arts',
#   'q_length': 111,
#   'qid': 132,
#   'uid': 71},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'sandro botticelli',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 108.28571428571429,
#   'avg_pos_uid': 42.727659574468085,
#   'category': 'fine arts',
#   'q_length': 111,
#   'qid': 132,
#   'uid': 30},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'sandro botticelli',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 108.28571428571429,
#   'avg_pos_uid': 31.233590733590734,
#   'category': 'fine arts',
#   'q_length': 111,
#   'qid': 132,
#   'uid': 62},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'sandro botticelli',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 108.28571428571429,
#   'avg_pos_uid': 51.299546142208776,
#   'category': 'fine arts',
#   'q_length': 111,
#   'qid': 132,
#   'uid': 42},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'sandro botticelli',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 108.28571428571429,
#   'avg_pos_uid': 48.99321266968326,
#   'category': 'fine arts',
#   'q_length': 111,
#   'qid': 132,
#   'uid': 10},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'school of athens',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 64.0,
#   'avg_pos_uid': 42.727659574468085,
#   'category': 'fine arts',
#   'q_length': 94,
#   'qid': 133,
#   'uid': 30},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'school of athens',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 64.0,
#   'avg_pos_uid': 33.85839160839161,
#   'category': 'fine arts',
#   'q_length': 94,
#   'qid': 133,
#   'uid': 43},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'potato eaters',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 30.0,
#   'avg_pos_uid': 49.20206489675516,
#   'category': 'fine arts',
#   'q_length': 99,
#   'qid': 135,
#   'uid': 18},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'potato eaters',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 30.0,
#   'avg_pos_uid': 70.61417322834646,
#   'category': 'fine arts',
#   'q_length': 99,
#   'qid': 135,
#   'uid': 44},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'potato eaters',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 30.0,
#   'avg_pos_uid': 35.77872340425532,
#   'category': 'fine arts',
#   'q_length': 99,
#   'qid': 135,
#   'uid': 19},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'potato eaters',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 30.0,
#   'avg_pos_uid': 39.55263157894737,
#   'category': 'fine arts',
#   'q_length': 99,
#   'qid': 135,
#   'uid': 21},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'potato eaters',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 30.0,
#   'avg_pos_uid': 49.725247524752476,
#   'category': 'fine arts',
#   'q_length': 99,
#   'qid': 135,
#   'uid': 24},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'potato eaters',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 30.0,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 99,
#   'qid': 135,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'potato eaters',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 30.0,
#   'avg_pos_uid': -16.507246376811594,
#   'category': 'fine arts',
#   'q_length': 99,
#   'qid': 135,
#   'uid': 59},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'potato eaters',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 30.0,
#   'avg_pos_uid': 26.5,
#   'category': 'fine arts',
#   'q_length': 99,
#   'qid': 135,
#   'uid': 89},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'potato eaters',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 30.0,
#   'avg_pos_uid': 31.45751633986928,
#   'category': 'fine arts',
#   'q_length': 99,
#   'qid': 135,
#   'uid': 12},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'potato eaters',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 30.0,
#   'avg_pos_uid': 44.89887640449438,
#   'category': 'fine arts',
#   'q_length': 99,
#   'qid': 135,
#   'uid': 63},
# ...
#   'avg_pos_qid': 71.3125,
#   'avg_pos_uid': 15.689655172413794,
#   'category': 'fine arts',
#   'q_length': 132,
#   'qid': 583,
#   'uid': 148},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'titian',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 71.3125,
#   'avg_pos_uid': 35.64,
#   'category': 'fine arts',
#   'q_length': 132,
#   'qid': 583,
#   'uid': 133},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'titian',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 71.3125,
#   'avg_pos_uid': 22.48,
#   'category': 'fine arts',
#   'q_length': 132,
#   'qid': 583,
#   'uid': 149},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'titian',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 71.3125,
#   'avg_pos_uid': 58.64485981308411,
#   'category': 'fine arts',
#   'q_length': 132,
#   'qid': 583,
#   'uid': 47},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'titian',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 71.3125,
#   'avg_pos_uid': 45.63157894736842,
#   'category': 'fine arts',
#   'q_length': 132,
#   'qid': 583,
#   'uid': 15},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'titian',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 71.3125,
#   'avg_pos_uid': 25.75886524822695,
#   'category': 'fine arts',
#   'q_length': 132,
#   'qid': 583,
#   'uid': 93},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'titian',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 71.3125,
#   'avg_pos_uid': -10.236363636363636,
#   'category': 'fine arts',
#   'q_length': 132,
#   'qid': 583,
#   'uid': 121},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'titian',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 71.3125,
#   'avg_pos_uid': 41.88,
#   'category': 'fine arts',
#   'q_length': 132,
#   'qid': 583,
#   'uid': 67},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'titian',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 71.3125,
#   'avg_pos_uid': 63.74074074074074,
#   'category': 'fine arts',
#   'q_length': 132,
#   'qid': 583,
#   'uid': 150},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'thomas gainsborough',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 126.0,
#   'avg_pos_uid': 35.77872340425532,
#   'category': 'fine arts',
#   'q_length': 126,
#   'qid': 584,
#   'uid': 19},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'thomas gainsborough',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 126.0,
#   'avg_pos_uid': 44.0092879256966,
#   'category': 'fine arts',
#   'q_length': 126,
#   'qid': 584,
#   'uid': 73},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'watson and the shark',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 34.6,
#   'avg_pos_uid': 35.77872340425532,
#   'category': 'fine arts',
#   'q_length': 131,
#   'qid': 585,
#   'uid': 19},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'watson and the shark',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 34.6,
#   'avg_pos_uid': 49.971377459749554,
#   'category': 'fine arts',
#   'q_length': 131,
#   'qid': 585,
#   'uid': 71},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'watson and the shark',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 34.6,
#   'avg_pos_uid': 44.0092879256966,
#   'category': 'fine arts',
#   'q_length': 131,
#   'qid': 585,
#   'uid': 73},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'watson and the shark',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 34.6,
#   'avg_pos_uid': 50.725352112676056,
#   'category': 'fine arts',
#   'q_length': 131,
#   'qid': 585,
#   'uid': 114},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'watson and the shark',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 34.6,
#   'avg_pos_uid': 31.45751633986928,
#   'category': 'fine arts',
#   'q_length': 131,
#   'qid': 585,
#   'uid': 12},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'maurice ravel',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 32.2,
#   'avg_pos_uid': 53.33957845433255,
#   'category': 'fine arts',
#   'q_length': 75,
#   'qid': 590,
#   'uid': 51},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'maurice ravel',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 32.2,
#   'avg_pos_uid': 32.4375,
#   'category': 'fine arts',
#   'q_length': 75,
#   'qid': 590,
#   'uid': 151},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'maurice ravel',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 32.2,
#   'avg_pos_uid': 31.45751633986928,
#   'category': 'fine arts',
#   'q_length': 75,
#   'qid': 590,
#   'uid': 12},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'maurice ravel',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 32.2,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 75,
#   'qid': 590,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'maurice ravel',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 32.2,
#   'avg_pos_uid': 58.64485981308411,
#   'category': 'fine arts',
#   'q_length': 75,
#   'qid': 590,
#   'uid': 47},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'henry purcell',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 8.166666666666666,
#   'avg_pos_uid': 53.559471365638764,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 595,
#   'uid': 54},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'henry purcell',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 8.166666666666666,
#   'avg_pos_uid': 42.727659574468085,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 595,
#   'uid': 30},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'henry purcell',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 8.166666666666666,
#   'avg_pos_uid': 38.577586206896555,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 595,
#   'uid': 14},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'henry purcell',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 8.166666666666666,
#   'avg_pos_uid': -2.2989690721649483,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 595,
#   'uid': 29},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'henry purcell',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 8.166666666666666,
#   'avg_pos_uid': 42.727659574468085,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 595,
#   'uid': 30},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'henry purcell',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 8.166666666666666,
#   'avg_pos_uid': 24.903614457831324,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 595,
#   'uid': 17},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'robert schumann',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 41.5,
#   'avg_pos_uid': 42.727659574468085,
#   'category': 'fine arts',
#   'q_length': 74,
#   'qid': 598,
#   'uid': 30},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'robert schumann',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 41.5,
#   'avg_pos_uid': 49.65835411471322,
#   'category': 'fine arts',
#   'q_length': 74,
#   'qid': 598,
#   'uid': 3},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 21.453488372093023,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 101},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 65,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 153},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 49.971377459749554,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 71},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 48.99321266968326,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 10},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 21.72222222222222,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 36},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 65,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 154},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 23.357142857142858,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 155},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 9.875,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 156},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 11.75,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 158},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 65,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 159},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 44.0,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 160},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 36.78260869565217,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 152},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 61.0,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 161},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 33.42857142857143,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 162},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'samuel barber',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 36.333333333333336,
#   'avg_pos_uid': 42.333333333333336,
#   'category': 'fine arts',
#   'q_length': 65,
#   'qid': 610,
#   'uid': 163},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'fidelio',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 79.8,
#   'avg_pos_uid': 39.55263157894737,
#   'category': 'literature',
#   'q_length': 116,
#   'qid': 612,
#   'uid': 21},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'fidelio',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 79.8,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'literature',
#   'q_length': 116,
#   'qid': 612,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'fidelio',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 79.8,
#   'avg_pos_uid': 36.80373831775701,
#   'category': 'literature',
#   'q_length': 116,
#   'qid': 612,
#   'uid': 6},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'fidelio',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 79.8,
#   'avg_pos_uid': 23.157894736842106,
#   'category': 'literature',
#   'q_length': 116,
#   'qid': 612,
#   'uid': 25},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'fidelio',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 79.8,
#   'avg_pos_uid': 32.4375,
#   'category': 'literature',
#   'q_length': 116,
#   'qid': 612,
#   'uid': 151},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'fidelio',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 79.8,
#   'avg_pos_uid': 35.71875,
#   'category': 'literature',
#   'q_length': 116,
#   'qid': 612,
#   'uid': 116},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'fidelio',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 79.8,
#   'avg_pos_uid': 30.973895582329316,
#   'category': 'literature',
#   'q_length': 116,
#   'qid': 612,
#   'uid': 1},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'fidelio',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 79.8,
#   'avg_pos_uid': 58.64485981308411,
#   'category': 'literature',
#   'q_length': 116,
#   'qid': 612,
#   'uid': 47},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'fidelio',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 79.8,
#   'avg_pos_uid': 42.727659574468085,
#   'category': 'literature',
#   'q_length': 116,
#   'qid': 612,
#   'uid': 30},
#  {'acc_ratio_cat': 0.7865739207243017,
#   'answer': 'fidelio',
#   'ave_pos_cat': 51.672628905818705,
#   'avg_pos_qid': 79.8,
#   'avg_pos_uid': 38.09090909090909,
#   'category': 'literature',
#   'q_length': 116,
#   'qid': 612,
#   'uid': 16},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'bassoon',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 57.5,
#   'avg_pos_uid': 42.727659574468085,
#   'category': 'fine arts',
#   'q_length': 85,
#   'qid': 615,
#   'uid': 30},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'bassoon',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 57.5,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 85,
#   'qid': 615,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'bela bartok',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 60.75,
#   'avg_pos_uid': 55.74681753889675,
#   'category': 'fine arts',
#   'q_length': 70,
#   'qid': 618,
#   'uid': 20},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'bela bartok',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 60.75,
#   'avg_pos_uid': 31.45751633986928,
#   'category': 'fine arts',
#   'q_length': 70,
#   'qid': 618,
#   'uid': 12},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'bela bartok',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 60.75,
#   'avg_pos_uid': 49.971377459749554,
#   'category': 'fine arts',
#   'q_length': 70,
#   'qid': 618,
#   'uid': 71},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'bela bartok',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 60.75,
#   'avg_pos_uid': 39.851063829787236,
#   'category': 'fine arts',
#   'q_length': 70,
#   'qid': 618,
#   'uid': 9},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'gustav mahler',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 14.0,
#   'avg_pos_uid': 50.3218085106383,
#   'category': 'fine arts',
#   'q_length': 75,
#   'qid': 619,
#   'uid': 98},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'gustav mahler',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 14.0,
#   'avg_pos_uid': 24.903614457831324,
#   'category': 'fine arts',
#   'q_length': 75,
#   'qid': 619,
#   'uid': 17},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'claudio monteverdi',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 40.42857142857143,
#   'avg_pos_uid': 42.727659574468085,
#   'category': 'fine arts',
#   'q_length': 91,
#   'qid': 624,
#   'uid': 30},
#  {'acc_ratio_cat': 0.7560975609756098,
#   'answer': 'claudio monteverdi',
#   'ave_pos_cat': 43.640185830429736,
#   'avg_pos_qid': 40.42857142857143,
#   'avg_pos_uid': 32.4375,
#   'category': 'fine arts',
#   'q_length': 91,
#   'qid': 624,
#   'uid': 151},
#  ...]

# %%
def transform(X):
    for index, item in enumerate(X):
        uid = int(item['uid'])
        qid = int(item['qid'])
        
        # uid
        if int(uid) in users:
            item['acc_ratio_uid'] = users[uid]['acc_ratio_uid']
            item['cat_uid'] = users[uid]['cat_uid']
        else:
            acc = users.select(['acc_ratio_uid'])
            item['acc_ratio_uid'] = sum(acc) / float(len(acc))
            item['cat_uid'] = most_pred_cat_uid

        # qid
        if int(qid) in questions:
            item['acc_ratio_qid'] = questions[qid]['acc_ratio_qid']
            item['cat_qid'] = questions[qid]['cat_qid']
        else:
            acc = questions.select(['acc_ratio_qid'])
            item['acc_ratio_qid'] = sum(acc) / float(len(acc))
            item['cat_qid'] = most_pred_cat_qid
        
        item['uid'] = str(uid)
        item['qid'] = str(qid)

# %%
transform(X_train)
X_train[1]
# Out:
# {'acc_ratio_cat': 0.7560975609756098,
#  'acc_ratio_qid': 0.875,
#  'acc_ratio_uid': 0.6465863453815262,
#  'answer': 'thomas cole',
#  'ave_pos_cat': 43.640185830429736,
#  'avg_pos_qid': 51.0,
#  'avg_pos_uid': 30.973895582329316,
#  'cat_qid': '6',
#  'cat_uid': '3',
#  'category': 'fine arts',
#  'q_length': 78,
#  'qid': '1',
#  'uid': '1'}

# %%
from sklearn.feature_extraction import DictVectorizer


vec = DictVectorizer()
X_train_dict_vec = vec.fit_transform(X_train)

# %%
import multiprocessing
from sklearn import linear_model
from sklearn.cross_validation import train_test_split, cross_val_score
import math
from numpy import abs, sqrt


regressor_names = """
ElasticNetCV
"""
#for l1 in [0.5, 0.2, 0.7, 0.9]:
for l1 in [0.5]:
    print ("=== ElasticNetCV RMSE", "with", l1)
    for regressor in regressor_names.split():
        scores = cross_val_score(getattr(linear_model, regressor)(n_jobs=3, normalize=True, l1_ratio = l1),
                                 X_train_dict_vec, y_train,
                                 cv=2,
                                 scoring='mean_squared_error'
                                )
        print (regressor, sqrt(abs(scores)).mean())
# Out:
# === ElasticNetCV RMSE with 0.5
# ElasticNetCV 78.9386912207

# %% [markdown]
# * n_iter=10: 78.9121215405
# * n_iter=100 take1: 78.9251743166
# * n_iter=100 take2: 78.9268663663

# %% [markdown]
# ### Training and testing model

# %%
regression_keys = ['category', 'q_length', 'qid', 'uid', 'answer', 'avg_pos_uid', 'avg_pos_qid']
X_train, y_train = featurize(load_buzz(), group='train', sign_val=None, extra=['avg_pos'])
X_train = select(X_train, regression_keys)
X_test = featurize(load_buzz(), group='test', sign_val=None, extra=['avg_pos'])
X_test = select(X_test, regression_keys)

transform(X_train)
transform(X_test)

for item in X_train:
    for key in categories[item['category']].keys():
        item[key] = categories[item['category']][key]

for item in X_test:
    for key in categories[item['category']].keys():
        item[key] = categories[item['category']][key]

# %%
X_train[1]
# Out:
# {'acc_ratio_cat': 0.7560975609756098,
#  'acc_ratio_qid': 0.875,
#  'acc_ratio_uid': 0.6465863453815262,
#  'answer': 'thomas cole',
#  'ave_pos_cat': 43.640185830429736,
#  'avg_pos_qid': 51.0,
#  'avg_pos_uid': 30.973895582329316,
#  'cat_qid': '6',
#  'cat_uid': '3',
#  'category': 'fine arts',
#  'q_length': 78,
#  'qid': '1',
#  'uid': '1'}

# %%
X_test[1]
# Out:
# {'acc_ratio_cat': 0.65625,
#  'acc_ratio_qid': 0.6428571428571429,
#  'acc_ratio_uid': 0.6712328767123288,
#  'answer': 'david hilbert',
#  'ave_pos_cat': 18.712499999999999,
#  'avg_pos_qid': 15.571428571428571,
#  'avg_pos_uid': 36.31506849315068,
#  'cat_qid': '6',
#  'cat_uid': '3',
#  'category': 'mathematics',
#  'q_length': 105,
#  'qid': '9967',
#  'uid': '131'}

# %%
vec = DictVectorizer()
vec.fit(X_train + X_test)
X_train = vec.transform(X_train)
X_test = vec.transform(X_test)

# %%
for l1_ratio in [0.5, 0.2, 0.6, 0.7, 0.8, 0.9]:
    print('=== l1_ratio:', l1_ratio)
    regressor = linear_model.ElasticNetCV(n_jobs=3, normalize=True, l1_ratio=l1_ratio)
    regressor.fit(X_train, y_train)
    print(regressor.coef_)
    print(regressor.alpha_)
    predictions = regressor.predict(X_test)
    write_result(load_buzz()['test'], predictions, file_name=str(l1_ratio)+'guess.csv')
# Out:
# === l1_ratio: 0.5
# [ 12.76297848  14.94823146  13.50376081 ...,   3.99211887   0.82483622
#    2.90424122]
# 0.000565901396911
# === l1_ratio: 0.2
# [ 5.2447881   4.84526527  4.39669113 ...,  1.15479725  0.28880723
#   0.93310611]
# 0.00141475349228
# === l1_ratio: 0.6
# [ 14.85216167  19.50479804  17.57888789 ...,   5.49255552   1.03948772
#    3.78856923]
# 0.000471584497426
# === l1_ratio: 0.7
# [ 16.45242058  25.00002044  22.46185688 ...,   7.51129398   1.27914953
#    4.83133989]
# 0.000404215283508
# === l1_ratio: 0.8
# [ 17.20082518  31.87996146  28.50063581 ...,  10.37202337   1.55933315
#    6.05050835]
# 0.000353688373069
# === l1_ratio: 0.9
# [ 16.30640914  41.37973269  36.47928909 ...,  14.82087285   1.93400448
#    7.26026656]
# 0.00031438966495
